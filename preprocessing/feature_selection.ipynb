# %%
import pandas as pd 

counties = pd.read_csv(r'..\_data\data_counties.csv')
municip = pd.read_csv(r'..\_data\data_municipalities.csv')

# %%
counties.isna().sum()
# Out:
# county_code                     0
# county_name                     0
# average_wage_relative           0
# doctors_per_1000_persons        0
# beds_in_hospitals               0
# cars_per_1000_persons           0
# motorcycles_per_1000_persons    0
# education_share_higher          0
# education_share_secondary       0
# education_share_vocational      0
# education_share_primary         0
# tourits_per_1000_persons        1
# dtype: int64

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
municip_merged = municip.merge(counties, on='county_code')

# %%
# The total population for each age group
municip_merged['population_below_25'] = municip_merged[['population_0_4_total', 'population_5_9_total', 'population_10_14_total', 'population_15_19_total', 'population_20_24_total']].sum(axis=1)
municip_merged['population_25_60'] = municip_merged[['population_25_29_total', 'population_30_34_total', 'population_35_39_total', 'population_40_44_total', 'population_45_49_total', 'population_50_54_total', 'population_55_59_total', 'population_60_64_total']].sum(axis=1)
municip_merged['population_over_60'] = municip_merged[['population_65_69_total', 'population_70_74_total', 'population_75_79_total', 'population_80_84_total']].sum(axis=1)

# Calculate total population
#municip_merged['population_total'] = municip_merged.iloc[:, 1:-3].sum(axis=1)

# Calculate percentages
municip_merged['percent_population_below_25'] = (municip_merged['population_below_25'] / municip_merged['population_total']) * 100
municip_merged['percent_population_25_60'] = (municip_merged['population_25_60'] / municip_merged['population_total']) * 100
municip_merged['percent_population_over_60'] = (municip_merged['population_over_60'] / municip_merged['population_total']) * 100

# Drop intermediate columns if needed
pops_to_drop = ['population_0_4_total', 'population_5_9_total', 'population_10_14_total', 'population_15_19_total', 'population_20_24_total',
'population_25_29_total', 'population_30_34_total', 'population_35_39_total', 'population_40_44_total', 'population_45_49_total',
'population_50_54_total', 'population_55_59_total', 'population_60_64_total', 'population_65_69_total', 'population_70_74_total', 'population_75_79_total', 'population_80_84_total']
municip_merged = municip_merged.drop(['population_below_25', 'population_25_60', 'population_over_60'], axis=1)
for pop_to_drop in pops_to_drop:
    municip_merged= municip_merged.drop([pop_to_drop, pop_to_drop+'_f', pop_to_drop+'_m'], axis=1)
municip_merged
# Out:
#       municipality_code municipality_name  county_code  percent_vaccinated  \
# 0                201011       Bolesławiec       201000                56.9
# 1                201022       Bolesławiec       201000                47.7
# 2                201032          Gromadka       201000                49.5
# 3                201043      Nowogrodziec       201000                47.5
# 4                201052        Osiecznica       201000                52.2
# ...                 ...               ...          ...                 ...
# 2472            3218043             Resko      3218000                55.0
# 2473            3218053         Węgorzyno      3218000                51.9
# 2474            3261011          Koszalin      3261000                61.0
# 2475            3262011          Szczecin      3262000                65.1
# 2476            3263011       Świnoujście      3263000                62.3
#
#       population_total  population_total_m  population_total_f  area_km2  \
# 0                37659               17610               20049        24
# 1                14967                7473                7494       289
# 2                 5156                2559                2597       268
# 3                14852                7414                7438       176
# 4                 7358                3703                3655       437
# ...                ...                 ...                 ...       ...
# 2472              7470                3744                3726       285
# 2473              6463                3260                3203       256
# 2474            106152               50107               56045        98
# 2475            397289              188454              208835       301
# 2476             40326               19356               20970       202
#
#       population_density  urbanization_rate  healthcare_advices  \
# 0                 1597.8              100.0            202393.0
# 1                   51.9                0.0             13532.0
# 2                   19.3                0.0             11221.0
# 3                   84.2               28.1             47211.0
# 4                   16.8                0.0             38508.0
# ...                  ...                ...                 ...
# 2472                26.2               54.2             12945.0
# 2473                25.2               41.2             12137.0
# 2474              1079.4              100.0            587171.0
# 2475              1321.7              100.0           1613617.0
# 2476               199.6              100.0            181472.0
#
#       population_per_pharmacy  installations_watersupply  \
# 0                        2092                       98.5
# 1                       14967                       97.8
# 2                        5156                       96.1
# 3                        3713                       96.8
# 4                        7358                       96.0
# ...                       ...                        ...
# 2472                     3735                       98.6
# 2473                     6463                       97.4
# 2474                     2308                       99.8
# 2475                     2614                       99.1
# 2476                     1920                       97.5
#
#       installations_toilet  installations_bathroom  \
# 0                     98.0                    97.5
# 1                     97.2                    95.3
# 2                     93.6                    91.8
# 3                     95.9                    94.4
# 4                     95.7                    93.9
# ...                    ...                     ...
# 2472                  94.9                    93.1
# 2473                  92.7                    89.8
# 2474                  99.1                    98.9
# 2475                  97.0                    96.7
# 2476                  96.6                    96.5
#
#       installations_central_heating  installations_network_gas  \
# 0                              87.1                       90.6
# 1                              83.2                       28.8
# 2                              79.1                        0.2
# 3                              77.3                       14.2
# 4                              71.6                        4.1
# ...                             ...                        ...
# 2472                           72.4                       27.6
# 2473                           72.2                        3.7
# 2474                           93.3                       87.6
# 2475                           90.5                       81.9
# 2476                           94.0                       69.6
#
#       appartment_area_per_person appartments_per_1000_persons  \
# 0                           28.7                        444.9
# 1                           36.3                        305.9
# 2                           30.9                        345.8
# 3                           28.0                        305.5
# 4                           30.8                        397.0
# ...                          ...                          ...
# 2472                        25.9                        373.1
# 2473                        26.6                        371.2
# 2474                        28.4                        451.4
# 2475                        29.2                        473.7
# 2476                        32.8                        553.8
#
#       persons_per_appartment  persons_per_room  persons_per_library  \
# 0                       2.25              0.64                18830
# 1                       3.27              0.64                 2495
# 2                       2.89              0.64                 5156
# 3                       3.27              0.69                 2970
# 4                       2.52              0.62                 1226
# ...                      ...               ...                  ...
# 2472                    2.68              0.70                 7470
# 2473                    2.69              0.71                 2154
# 2474                    2.22              0.63                 9650
# 2475                    2.11              0.62                11036
# 2476                    1.81              0.55                 6721
#
#       library_books_per_1000_persons  library_readers_per_1000_persons  \
# 0                               2959                               143
# 1                               4849                               119
# 2                               2921                                37
# 3                               2939                                48
# 4                               6674                               167
# ...                              ...                               ...
# 2472                            4272                                77
# 2473                            3068                               141
# 2474                            3535                               131
# 2475                            4551                               126
# 2476                            3456                                76
#
#       library_loans_per_reader  forests_area unemployed_total unemployed_f  \
# 0                         11.3         75.18              761          409
# 1                         12.2        230.52              286          149
# 2                         12.6        204.00              119           73
# 3                          8.3        251.00              342          192
# 4                          7.8         43.13              175           93
# ...                        ...           ...              ...          ...
# 2472                      21.7        249.78              535          249
# 2473                      19.8        275.15              315          199
# 2474                      17.0        123.16            3 151        1 594
# 2475                      13.8       2745.55            7 177        3 386
# 2476                      17.9         83.94              714          369
#
#      unemployed_m unemployed_up_to_25 unemployed_over_50 unemployed_long_term  \
# 0             352                  70                187                  275
# 1             137                  52                 72                  105
# 2              46                  17                 27                   47
# 3             150                  57                 82                  135
# 4              82                  23                 41                   74
# ...           ...                 ...                ...                  ...
# 2472          286                  82                137                  342
# 2473          116                  42                 97                  203
# 2474        1 557                 215                949                1 455
# 2475        3 791                 479              2 182                2 279
# 2476          345                  44                250                  263
#
#       unemployment_rate  unemployment_rate_m  unemployment_rate_f  \
# 0                   3.6                  3.1                  4.1
# 1                   3.1                  2.8                  3.5
# 2                   3.8                  2.7                  5.2
# 3                   3.7                  3.0                  4.6
# 4                   3.8                  3.3                  4.5
# ...                 ...                  ...                  ...
# 2472               12.1                 11.5                 12.9
# 2473                8.2                  5.4                 11.9
# 2474                5.2                  4.9                  5.5
# 2475                3.1                  3.1                  3.0
# 2476                3.0                  2.7                  3.4
#
#       bicycle_paths_per_100km2  bicycle_paths_per_10k_persons  \
# 0                       157.40                           9.85
# 1                         3.95                           7.62
# 2                         0.00                           0.00
# 3                         0.00                           0.00
# 4                         0.00                           0.00
# ...                        ...                            ...
# 2472                      0.42                           1.61
# 2473                      0.00                           0.00
# 2474                     89.59                           8.30
# 2475                     49.43                           3.74
# 2476                     21.13                          10.59
#
#       revenues_per_capita  revenues_per_capita_PIT  revenues_per_capita_CIT  \
# 0                 5312.66                  1067.74                    56.58
# 1                 5396.32                   926.60                    11.74
# 2                 8219.43                   690.41                   162.36
# 3                 5067.58                   644.43                    30.53
# 4                 6377.16                   786.19                    27.93
# ...                   ...                      ...                      ...
# 2472              6000.71                   878.57                    33.35
# 2473              8185.84                   537.42                    20.72
# 2474              6985.42                  1561.14                    96.76
# 2475              7659.20                  1553.30                   107.36
# 2476             14981.14                  1335.41                    78.14
#
#       expenditures_per_capita  investment_expenditures_per_capita  \
# 0                     4962.55                              142.34
# 1                     4859.22                              895.71
# 2                     6318.14                             1196.25
# 3                     4972.40                              379.00
# 4                     4837.36                              282.14
# ...                       ...                                 ...
# 2472                  6092.76                             1068.83
# 2473                  7295.62                             2256.17
# 2474                  6789.54                              721.10
# 2475                  8333.52                             2102.52
# 2476                 16358.25                             9065.35
#
#       children_3_5_in_kindergartens  net_scholarization  \
# 0                            1117.0              113.11
# 1                             581.0               68.29
# 2                             662.0               89.37
# 3                             615.0               84.88
# 4                             762.0              100.15
# ...                             ...                 ...
# 2472                          784.0               81.63
# 2473                          694.0               71.07
# 2474                         1056.0              105.84
# 2475                          976.0              101.78
# 2476                          974.0               98.19
#
#       marriages_per_1000_persons  birthrate_per_1000_persons  \
# 0                            3.2                       -6.04
# 1                            3.2                       -0.60
# 2                            2.1                       -3.48
# 3                            4.1                       -0.67
# 4                            4.8                       -2.15
# ...                          ...                         ...
# 2472                         3.1                      -11.69
# 2473                         3.6                       -5.87
# 2474                         3.7                       -4.08
# 2475                         4.3                       -4.62
# 2476                         4.1                       -4.85
#
#       net_migrations_per_1000_persons  persons_running_business  \
# 0                                -5.3                      3099
# 1                                12.5                      1431
# 2                                -1.4                       257
# 3                                 0.5                      1070
# 4                                 1.7                       539
# ...                               ...                       ...
# 2472                             -1.5                       562
# 2473                             -1.9                       387
# 2474                             -1.3                     13149
# 2475                             -0.8                     48648
# 2476                              3.2                      5024
#
#       entities_registered_per_10k_persons     county_name  \
# 0                                    1323   bolesławiecki
# 1                                    1086   bolesławiecki
# 2                                     673   bolesławiecki
# 3                                     871   bolesławiecki
# 4                                     896   bolesławiecki
# ...                                   ...             ...
# 2472                                 1068         łobeski
# 2473                                  839         łobeski
# 2474                                 1688     m. Koszalin
# 2475                                 1781     m. Szczecin
# 2476                                 1636  m. Świnoujście
#
#       average_wage_relative  doctors_per_1000_persons  beds_in_hospitals  \
# 0                      88.5                      14.3                235
# 1                      88.5                      14.3                235
# 2                      88.5                      14.3                235
# 3                      88.5                      14.3                235
# 4                      88.5                      14.3                235
# ...                     ...                       ...                ...
# 2472                   85.3                       7.8                  0
# 2473                   85.3                       7.8                  0
# 2474                   90.0                      39.5                580
# 2475                  103.1                      68.0               3283
# 2476                   99.9                      15.1                112
#
#       cars_per_1000_persons  motorcycles_per_1000_persons  \
# 0                     613.5                          31.4
# 1                     613.5                          31.4
# 2                     613.5                          31.4
# 3                     613.5                          31.4
# 4                     613.5                          31.4
# ...                     ...                           ...
# 2472                  691.4                          75.0
# 2473                  691.4                          75.0
# 2474                  569.4                          20.2
# 2475                  595.8                          24.2
# 2476                  578.1                          40.9
#
#       education_share_higher  education_share_secondary  \
# 0                      17.43                      35.08
# 1                      17.43                      35.08
# 2                      17.43                      35.08
# 3                      17.43                      35.08
# 4                      17.43                      35.08
# ...                      ...                        ...
# 2472                   12.98                      31.97
# 2473                   12.98                      31.97
# 2474                   29.82                      36.16
# 2475                   32.73                      34.85
# 2476                   22.58                      39.23
#
#       education_share_vocational  education_share_primary  \
# 0                          25.51                    15.85
# 1                          25.51                    15.85
# 2                          25.51                    15.85
# 3                          25.51                    15.85
# 4                          25.51                    15.85
# ...                          ...                      ...
# 2472                       25.33                    23.32
# 2473                       25.33                    23.32
# 2474                       16.67                    11.44
# 2475                       15.76                    10.81
# 2476                       19.42                    12.39
#
#       tourits_per_1000_persons  percent_population_below_25  \
# 0                       427.36                    21.349478
# 1                       427.36                    28.001604
# 2                       427.36                    25.019395
# 3                       427.36                    27.699973
# 4                       427.36                    28.146235
# ...                        ...                          ...
# 2472                    186.00                    24.939759
# 2473                    186.00                    26.226211
# 2474                      0.00                    21.740523
# 2475                    553.79                    21.919812
# 2476                   6948.44                    19.692010
#
#       percent_population_25_60  percent_population_over_60
# 0                    55.524576                   20.563478
# 1                    57.960847                   12.901717
# 2                    56.923972                   15.981381
# 3                    57.769997                   12.941018
# 4                    57.597173                   12.666485
# ...                        ...                         ...
# 2472                 55.876841                   16.840696
# 2473                 55.423178                   16.122544
# 2474                 55.757781                   19.907303
# 2475                 56.716899                   18.799161
# 2476                 57.603035                   20.686406
#
# [2477 rows x 63 columns]

# %%
municip_merged.to_csv('..\_data\data_municipalies_merged.csv', index = False)

# %%
cols_to_drop = ['installations_watersupply','installations_toilet','installations_bathroom', 'installations_central_heating', 'installations_central_heating', 
               	'appartment_area_per_person', 'persons_per_appartment',	'persons_per_room', 'library_books_per_1000_persons', 'library_loans_per_reader',
                'unemployed_total',	'unemployed_f',	'unemployed_m'	,'unemployed_up_to_25',	'unemployed_over_50',	'unemployed_long_term',
                'bicycle_paths_per_100km2',	'bicycle_paths_per_10k_persons', 'expenditures_per_capita',	'investment_expenditures_per_capita',	'children_3_5_in_kindergartens',
                'marriages_per_1000_persons',	'birthrate_per_1000_persons',	'net_migrations_per_1000_persons',	'persons_running_business',	'entities_registered_per_10k_persons',
                'beds_in_hospitals',	'cars_per_1000_persons',	'motorcycles_per_1000_persons']

municip_merged.drop(cols_to_drop, axis=1, inplace=True)
municip_merged
# Out:
#       municipality_code municipality_name  county_code  percent_vaccinated  \
# 0                201011       Bolesławiec       201000                56.9
# 1                201022       Bolesławiec       201000                47.7
# 2                201032          Gromadka       201000                49.5
# 3                201043      Nowogrodziec       201000                47.5
# 4                201052        Osiecznica       201000                52.2
# ...                 ...               ...          ...                 ...
# 2472            3218043             Resko      3218000                55.0
# 2473            3218053         Węgorzyno      3218000                51.9
# 2474            3261011          Koszalin      3261000                61.0
# 2475            3262011          Szczecin      3262000                65.1
# 2476            3263011       Świnoujście      3263000                62.3
#
#       population_total  population_total_m  population_total_f  area_km2  \
# 0                37659               17610               20049        24
# 1                14967                7473                7494       289
# 2                 5156                2559                2597       268
# 3                14852                7414                7438       176
# 4                 7358                3703                3655       437
# ...                ...                 ...                 ...       ...
# 2472              7470                3744                3726       285
# 2473              6463                3260                3203       256
# 2474            106152               50107               56045        98
# 2475            397289              188454              208835       301
# 2476             40326               19356               20970       202
#
#       population_density  urbanization_rate  healthcare_advices  \
# 0                 1597.8              100.0            202393.0
# 1                   51.9                0.0             13532.0
# 2                   19.3                0.0             11221.0
# 3                   84.2               28.1             47211.0
# 4                   16.8                0.0             38508.0
# ...                  ...                ...                 ...
# 2472                26.2               54.2             12945.0
# 2473                25.2               41.2             12137.0
# 2474              1079.4              100.0            587171.0
# 2475              1321.7              100.0           1613617.0
# 2476               199.6              100.0            181472.0
#
#       population_per_pharmacy  installations_network_gas  \
# 0                        2092                       90.6
# 1                       14967                       28.8
# 2                        5156                        0.2
# 3                        3713                       14.2
# 4                        7358                        4.1
# ...                       ...                        ...
# 2472                     3735                       27.6
# 2473                     6463                        3.7
# 2474                     2308                       87.6
# 2475                     2614                       81.9
# 2476                     1920                       69.6
#
#      appartments_per_1000_persons  persons_per_library  \
# 0                           444.9                18830
# 1                           305.9                 2495
# 2                           345.8                 5156
# 3                           305.5                 2970
# 4                           397.0                 1226
# ...                           ...                  ...
# 2472                        373.1                 7470
# 2473                        371.2                 2154
# 2474                        451.4                 9650
# 2475                        473.7                11036
# 2476                        553.8                 6721
#
#       library_readers_per_1000_persons  forests_area  unemployment_rate  \
# 0                                  143         75.18                3.6
# 1                                  119        230.52                3.1
# 2                                   37        204.00                3.8
# 3                                   48        251.00                3.7
# 4                                  167         43.13                3.8
# ...                                ...           ...                ...
# 2472                                77        249.78               12.1
# 2473                               141        275.15                8.2
# 2474                               131        123.16                5.2
# 2475                               126       2745.55                3.1
# 2476                                76         83.94                3.0
#
#       unemployment_rate_m  unemployment_rate_f  revenues_per_capita  \
# 0                     3.1                  4.1              5312.66
# 1                     2.8                  3.5              5396.32
# 2                     2.7                  5.2              8219.43
# 3                     3.0                  4.6              5067.58
# 4                     3.3                  4.5              6377.16
# ...                   ...                  ...                  ...
# 2472                 11.5                 12.9              6000.71
# 2473                  5.4                 11.9              8185.84
# 2474                  4.9                  5.5              6985.42
# 2475                  3.1                  3.0              7659.20
# 2476                  2.7                  3.4             14981.14
#
#       revenues_per_capita_PIT  revenues_per_capita_CIT  net_scholarization  \
# 0                     1067.74                    56.58              113.11
# 1                      926.60                    11.74               68.29
# 2                      690.41                   162.36               89.37
# 3                      644.43                    30.53               84.88
# 4                      786.19                    27.93              100.15
# ...                       ...                      ...                 ...
# 2472                   878.57                    33.35               81.63
# 2473                   537.42                    20.72               71.07
# 2474                  1561.14                    96.76              105.84
# 2475                  1553.30                   107.36              101.78
# 2476                  1335.41                    78.14               98.19
#
#          county_name  average_wage_relative  doctors_per_1000_persons  \
# 0      bolesławiecki                   88.5                      14.3
# 1      bolesławiecki                   88.5                      14.3
# 2      bolesławiecki                   88.5                      14.3
# 3      bolesławiecki                   88.5                      14.3
# 4      bolesławiecki                   88.5                      14.3
# ...              ...                    ...                       ...
# 2472         łobeski                   85.3                       7.8
# 2473         łobeski                   85.3                       7.8
# 2474     m. Koszalin                   90.0                      39.5
# 2475     m. Szczecin                  103.1                      68.0
# 2476  m. Świnoujście                   99.9                      15.1
#
#       education_share_higher  education_share_secondary  \
# 0                      17.43                      35.08
# 1                      17.43                      35.08
# 2                      17.43                      35.08
# 3                      17.43                      35.08
# 4                      17.43                      35.08
# ...                      ...                        ...
# 2472                   12.98                      31.97
# 2473                   12.98                      31.97
# 2474                   29.82                      36.16
# 2475                   32.73                      34.85
# 2476                   22.58                      39.23
#
#       education_share_vocational  education_share_primary  \
# 0                          25.51                    15.85
# 1                          25.51                    15.85
# 2                          25.51                    15.85
# 3                          25.51                    15.85
# 4                          25.51                    15.85
# ...                          ...                      ...
# 2472                       25.33                    23.32
# 2473                       25.33                    23.32
# 2474                       16.67                    11.44
# 2475                       15.76                    10.81
# 2476                       19.42                    12.39
#
#       tourits_per_1000_persons  percent_population_below_25  \
# 0                       427.36                    21.349478
# 1                       427.36                    28.001604
# 2                       427.36                    25.019395
# 3                       427.36                    27.699973
# 4                       427.36                    28.146235
# ...                        ...                          ...
# 2472                    186.00                    24.939759
# 2473                    186.00                    26.226211
# 2474                      0.00                    21.740523
# 2475                    553.79                    21.919812
# 2476                   6948.44                    19.692010
#
#       percent_population_25_60  percent_population_over_60
# 0                    55.524576                   20.563478
# 1                    57.960847                   12.901717
# 2                    56.923972                   15.981381
# 3                    57.769997                   12.941018
# 4                    57.597173                   12.666485
# ...                        ...                         ...
# 2472                 55.876841                   16.840696
# 2473                 55.423178                   16.122544
# 2474                 55.757781                   19.907303
# 2475                 56.716899                   18.799161
# 2476                 57.603035                   20.686406
#
# [2477 rows x 35 columns]

# %%
## Poglądy polityczne
opinie = pd.read_csv('..\_data\wyniki_gl_na_listy_po_gminach_proc_sejm.csv',sep=';')
opinie
# Out:
#       Kod TERYT             Gmina         Powiat         Województwo  \
# 0         20101    m. Bolesławiec  bolesławiecki        dolnośląskie
# 1         20102   gm. Bolesławiec  bolesławiecki        dolnośląskie
# 2         20103      gm. Gromadka  bolesławiecki        dolnośląskie
# 3         20104  gm. Nowogrodziec  bolesławiecki        dolnośląskie
# 4         20105    gm. Osiecznica  bolesławiecki        dolnośląskie
# ...         ...               ...            ...                 ...
# 2491     321804         gm. Resko        łobeski  zachodniopomorskie
# 2492     321805     gm. Węgorzyno        łobeski  zachodniopomorskie
# 2493     326101       m. Koszalin       Koszalin  zachodniopomorskie
# 2494     326201       m. Szczecin       Szczecin  zachodniopomorskie
# 2495     326301    m. Świnoujście    Świnoujście  zachodniopomorskie
#
#      Frekwencja % głosów nieważnych  \
# 0         60,88                1,15
# 1         56,54                1,47
# 2         52,83                2,42
# 3         48,79                1,91
# 4         49,94                2,49
# ...         ...                 ...
# 2491      46,70                2,40
# 2492      46,74                1,92
# 2493      65,27                1,01
# 2494      66,56                0,74
# 2495      61,97                0,70
#
#      W tym z powodu postawienia znaku „X” obok nazwiska dwóch lub większej liczby kandydatów z różnych list  \
# 0                                                 46,19
# 1                                                 58,06
# 2                                                 81,82
# 3                                                 63,30
# 4                                                 65,67
# ...                                                 ...
# 2491                                              67,65
# 2492                                              71,43
# 2493                                              63,38
# 2494                                              50,85
# 2495                                              43,57
#
#      W tym z powodu niepostawienia znaku „X” obok nazwiska żadnego kandydata  \
# 0                                                 53,81
# 1                                                 41,94
# 2                                                 18,18
# 3                                                 36,70
# 4                                                 34,33
# ...                                                 ...
# 2491                                              32,35
# 2492                                              28,57
# 2493                                              36,62
# 2494                                              49,15
# 2495                                              56,43
#
#      W tym z powodu postawienia znaku „X” wyłącznie obok nazwiska kandydata na liście której rejestracja została unieważniona  \
# 0                                                  0,00
# 1                                                  0,00
# 2                                                  0,00
# 3                                                  0,00
# 4                                                  0,00
# ...                                                 ...
# 2491                                               0,00
# 2492                                               0,00
# 2493                                               0,00
# 2494                                               0,00
# 2495                                               0,00
#
#      % głosów ważnych  \
# 0               98,85
# 1               98,53
# 2               97,58
# 3               98,09
# 4               97,51
# ...               ...
# 2491            97,60
# 2492            98,08
# 2493            98,99
# 2494            99,26
# 2495            99,30
#
#      KOALICYJNY KOMITET WYBORCZY KOALICJA OBYWATELSKA PO .N IPL ZIELONI - ZPOW-601-6/19  \
# 0                                                 23,95
# 1                                                 19,24
# 2                                                 12,93
# 3                                                 15,70
# 4                                                 19,38
# ...                                                 ...
# 2491                                              28,53
# 2492                                              23,13
# 2493                                              38,39
# 2494                                              40,47
# 2495                                              33,44
#
#      KOMITET WYBORCZY AKCJA ZAWIEDZIONYCH EMERYTÓW RENCISTÓW - ZPOW-601-21/19  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2491                                                NaN
# 2492                                                NaN
# 2493                                                NaN
# 2494                                                NaN
# 2495                                                NaN
#
#      KOMITET WYBORCZY KONFEDERACJA WOLNOŚĆ I NIEPODLEGŁOŚĆ - ZPOW-601-5/19  \
# 0                                                  6,16
# 1                                                  7,58
# 2                                                  5,27
# 3                                                  7,73
# 4                                                  6,97
# ...                                                 ...
# 2491                                               5,29
# 2492                                               5,75
# 2493                                               5,96
# 2494                                               6,79
# 2495                                               5,32
#
#      KOMITET WYBORCZY POLSKIE STRONNICTWO LUDOWE - ZPOW-601-19/19  \
# 0                                                  5,40
# 1                                                  9,27
# 2                                                  6,94
# 3                                                  9,60
# 4                                                  8,23
# ...                                                 ...
# 2491                                              11,01
# 2492                                              12,82
# 2493                                               7,75
# 2494                                               4,64
# 2495                                               4,36
#
#      KOMITET WYBORCZY PRAWICA - ZPOW-601-20/19  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 2491                                       NaN
# 2492                                       NaN
# 2493                                       NaN
# 2494                                       NaN
# 2495                                       NaN
#
#      KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ - ZPOW-601-9/19  \
# 0                                                 35,83
# 1                                                 43,64
# 2                                                 50,81
# 3                                                 53,30
# 4                                                 45,70
# ...                                                 ...
# 2491                                              40,66
# 2492                                              48,22
# 2493                                              29,59
# 2494                                              32,13
# 2495                                              30,18
#
#      KOMITET WYBORCZY SKUTECZNI PIOTRA LIROYA-MARCA - ZPOW-601-17/19  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2491                                                NaN
# 2492                                                NaN
# 2493                                                NaN
# 2494                                                NaN
# 2495                                                NaN
#
#      KOMITET WYBORCZY SOJUSZ LEWICY DEMOKRATYCZNEJ - ZPOW-601-1/19  \
# 0                                                 22,22
# 1                                                 14,94
# 2                                                 19,28
# 3                                                  9,75
# 4                                                 15,61
# ...                                                 ...
# 2491                                              14,52
# 2492                                              10,07
# 2493                                              18,32
# 2494                                              15,97
# 2495                                              26,70
#
#      KOMITET WYBORCZY WYBORCÓW KOALICJA BEZPARTYJNI I SAMORZĄDOWCY - ZPOW-601-10/19  \
# 0                                                  6,44
# 1                                                  5,32
# 2                                                  4,77
# 3                                                  3,92
# 4                                                  4,11
# ...                                                 ...
# 2491                                                NaN
# 2492                                                NaN
# 2493                                                NaN
# 2494                                                NaN
# 2495                                                NaN
#
#      KOMITET WYBORCZY WYBORCÓW MNIEJSZOŚĆ NIEMIECKA - ZPOW-601-15/19
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2491                                                NaN
# 2492                                                NaN
# 2493                                                NaN
# 2494                                                NaN
# 2495                                                NaN
#
# [2496 rows x 20 columns]

# %%
opinie = opinie[['Kod TERYT', 'Frekwencja', '% głosów nieważnych', 'Województwo',
 'KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ - ZPOW-601-9/19',
 'KOALICYJNY KOMITET WYBORCZY KOALICJA OBYWATELSKA PO .N IPL ZIELONI - ZPOW-601-6/19',
 'KOMITET WYBORCZY KONFEDERACJA WOLNOŚĆ I NIEPODLEGŁOŚĆ - ZPOW-601-5/19',
 'KOMITET WYBORCZY POLSKIE STRONNICTWO LUDOWE - ZPOW-601-19/19',
 'KOMITET WYBORCZY SOJUSZ LEWICY DEMOKRATYCZNEJ - ZPOW-601-1/19']]

opinie.columns = ['municipality_code', 'election_presence', 'percent_invalid_votes', 'voivodeship',
                   'PIS_party', 'KO_party', 'KONFEDERACJA_party', 'PSL_party', 'SLD_party']

# %%
import re
municip_merged['municipality_code_old'] = municip_merged['municipality_code']
municip_merged['municipality_code'] = municip_merged['municipality_code'].map(lambda x: int(str(x)[0:-1]))
municip_merged['municipality_code']
# Out:
# 0        20101
# 1        20102
# 2        20103
# 3        20104
# 4        20105
#          ...
# 2472    321804
# 2473    321805
# 2474    326101
# 2475    326201
# 2476    326301
# Name: municipality_code, Length: 2477, dtype: int64

# %%
municip_merged
# Out:
#       municipality_code municipality_name  county_code  percent_vaccinated  \
# 0                 20101       Bolesławiec       201000                56.9
# 1                 20102       Bolesławiec       201000                47.7
# 2                 20103          Gromadka       201000                49.5
# 3                 20104      Nowogrodziec       201000                47.5
# 4                 20105        Osiecznica       201000                52.2
# ...                 ...               ...          ...                 ...
# 2472             321804             Resko      3218000                55.0
# 2473             321805         Węgorzyno      3218000                51.9
# 2474             326101          Koszalin      3261000                61.0
# 2475             326201          Szczecin      3262000                65.1
# 2476             326301       Świnoujście      3263000                62.3
#
#       population_total  population_total_m  population_total_f  area_km2  \
# 0                37659               17610               20049        24
# 1                14967                7473                7494       289
# 2                 5156                2559                2597       268
# 3                14852                7414                7438       176
# 4                 7358                3703                3655       437
# ...                ...                 ...                 ...       ...
# 2472              7470                3744                3726       285
# 2473              6463                3260                3203       256
# 2474            106152               50107               56045        98
# 2475            397289              188454              208835       301
# 2476             40326               19356               20970       202
#
#       population_density  urbanization_rate  healthcare_advices  \
# 0                 1597.8              100.0            202393.0
# 1                   51.9                0.0             13532.0
# 2                   19.3                0.0             11221.0
# 3                   84.2               28.1             47211.0
# 4                   16.8                0.0             38508.0
# ...                  ...                ...                 ...
# 2472                26.2               54.2             12945.0
# 2473                25.2               41.2             12137.0
# 2474              1079.4              100.0            587171.0
# 2475              1321.7              100.0           1613617.0
# 2476               199.6              100.0            181472.0
#
#       population_per_pharmacy  installations_network_gas  \
# 0                        2092                       90.6
# 1                       14967                       28.8
# 2                        5156                        0.2
# 3                        3713                       14.2
# 4                        7358                        4.1
# ...                       ...                        ...
# 2472                     3735                       27.6
# 2473                     6463                        3.7
# 2474                     2308                       87.6
# 2475                     2614                       81.9
# 2476                     1920                       69.6
#
#      appartments_per_1000_persons  persons_per_library  \
# 0                           444.9                18830
# 1                           305.9                 2495
# 2                           345.8                 5156
# 3                           305.5                 2970
# 4                           397.0                 1226
# ...                           ...                  ...
# 2472                        373.1                 7470
# 2473                        371.2                 2154
# 2474                        451.4                 9650
# 2475                        473.7                11036
# 2476                        553.8                 6721
#
#       library_readers_per_1000_persons  forests_area  unemployment_rate  \
# 0                                  143         75.18                3.6
# 1                                  119        230.52                3.1
# 2                                   37        204.00                3.8
# 3                                   48        251.00                3.7
# 4                                  167         43.13                3.8
# ...                                ...           ...                ...
# 2472                                77        249.78               12.1
# 2473                               141        275.15                8.2
# 2474                               131        123.16                5.2
# 2475                               126       2745.55                3.1
# 2476                                76         83.94                3.0
#
#       unemployment_rate_m  unemployment_rate_f  revenues_per_capita  \
# 0                     3.1                  4.1              5312.66
# 1                     2.8                  3.5              5396.32
# 2                     2.7                  5.2              8219.43
# 3                     3.0                  4.6              5067.58
# 4                     3.3                  4.5              6377.16
# ...                   ...                  ...                  ...
# 2472                 11.5                 12.9              6000.71
# 2473                  5.4                 11.9              8185.84
# 2474                  4.9                  5.5              6985.42
# 2475                  3.1                  3.0              7659.20
# 2476                  2.7                  3.4             14981.14
#
#       revenues_per_capita_PIT  revenues_per_capita_CIT  net_scholarization  \
# 0                     1067.74                    56.58              113.11
# 1                      926.60                    11.74               68.29
# 2                      690.41                   162.36               89.37
# 3                      644.43                    30.53               84.88
# 4                      786.19                    27.93              100.15
# ...                       ...                      ...                 ...
# 2472                   878.57                    33.35               81.63
# 2473                   537.42                    20.72               71.07
# 2474                  1561.14                    96.76              105.84
# 2475                  1553.30                   107.36              101.78
# 2476                  1335.41                    78.14               98.19
#
#          county_name  average_wage_relative  doctors_per_1000_persons  \
# 0      bolesławiecki                   88.5                      14.3
# 1      bolesławiecki                   88.5                      14.3
# 2      bolesławiecki                   88.5                      14.3
# 3      bolesławiecki                   88.5                      14.3
# 4      bolesławiecki                   88.5                      14.3
# ...              ...                    ...                       ...
# 2472         łobeski                   85.3                       7.8
# 2473         łobeski                   85.3                       7.8
# 2474     m. Koszalin                   90.0                      39.5
# 2475     m. Szczecin                  103.1                      68.0
# 2476  m. Świnoujście                   99.9                      15.1
#
#       education_share_higher  education_share_secondary  \
# 0                      17.43                      35.08
# 1                      17.43                      35.08
# 2                      17.43                      35.08
# 3                      17.43                      35.08
# 4                      17.43                      35.08
# ...                      ...                        ...
# 2472                   12.98                      31.97
# 2473                   12.98                      31.97
# 2474                   29.82                      36.16
# 2475                   32.73                      34.85
# 2476                   22.58                      39.23
#
#       education_share_vocational  education_share_primary  \
# 0                          25.51                    15.85
# 1                          25.51                    15.85
# 2                          25.51                    15.85
# 3                          25.51                    15.85
# 4                          25.51                    15.85
# ...                          ...                      ...
# 2472                       25.33                    23.32
# 2473                       25.33                    23.32
# 2474                       16.67                    11.44
# 2475                       15.76                    10.81
# 2476                       19.42                    12.39
#
#       tourits_per_1000_persons  percent_population_below_25  \
# 0                       427.36                    21.349478
# 1                       427.36                    28.001604
# 2                       427.36                    25.019395
# 3                       427.36                    27.699973
# 4                       427.36                    28.146235
# ...                        ...                          ...
# 2472                    186.00                    24.939759
# 2473                    186.00                    26.226211
# 2474                      0.00                    21.740523
# 2475                    553.79                    21.919812
# 2476                   6948.44                    19.692010
#
#       percent_population_25_60  percent_population_over_60  \
# 0                    55.524576                   20.563478
# 1                    57.960847                   12.901717
# 2                    56.923972                   15.981381
# 3                    57.769997                   12.941018
# 4                    57.597173                   12.666485
# ...                        ...                         ...
# 2472                 55.876841                   16.840696
# 2473                 55.423178                   16.122544
# 2474                 55.757781                   19.907303
# 2475                 56.716899                   18.799161
# 2476                 57.603035                   20.686406
#
#       municipality_code_old
# 0                    201011
# 1                    201022
# 2                    201032
# 3                    201043
# 4                    201052
# ...                     ...
# 2472                3218043
# 2473                3218053
# 2474                3261011
# 2475                3262011
# 2476                3263011
#
# [2477 rows x 36 columns]

# %%
opinie.head()
# Out:
#    municipality_code election_presence percent_invalid_votes   voivodeship  \
# 0              20101             60,88                  1,15  dolnośląskie
# 1              20102             56,54                  1,47  dolnośląskie
# 2              20103             52,83                  2,42  dolnośląskie
# 3              20104             48,79                  1,91  dolnośląskie
# 4              20105             49,94                  2,49  dolnośląskie
#
#   PIS_party KO_party KONFEDERACJA_party PSL_party SLD_party
# 0     35,83    23,95               6,16      5,40     22,22
# 1     43,64    19,24               7,58      9,27     14,94
# 2     50,81    12,93               5,27      6,94     19,28
# 3     53,30    15,70               7,73      9,60      9,75
# 4     45,70    19,38               6,97      8,23     15,61

# %%
municip_merged = municip_merged.merge(opinie, on='municipality_code', how='left')

# %%
municip_merged.to_csv('data_municipality_final.csv', index=False)

# %%
municip_merged[municip_merged['PIS_party'].isna()]
# Out:
#       municipality_code municipality_name  county_code  percent_vaccinated  \
# 1280             146501          Warszawa      1465000                76.0
#
#       population_total  population_total_m  population_total_f  area_km2  \
# 1280           1861774              858762             1003012       517
#
#       population_density  urbanization_rate  healthcare_advices  \
# 1280              3599.4              100.0           5698702.0
#
#       population_per_pharmacy  installations_network_gas  \
# 1280                     3093                       71.7
#
#      appartments_per_1000_persons  persons_per_library  \
# 1280                        555.1                 7026
#
#       library_readers_per_1000_persons  forests_area  unemployment_rate  \
# 1280                               189       2924.56                2.2
#
#       unemployment_rate_m  unemployment_rate_f  revenues_per_capita  \
# 1280                  2.2                  2.1              9970.89
#
#       revenues_per_capita_PIT  revenues_per_capita_CIT  net_scholarization  \
# 1280                  3302.09                   545.73               99.51
#
#           county_name  average_wage_relative  doctors_per_1000_persons  \
# 1280  m. st. Warszawa                  129.4                      48.9
#
#       education_share_higher  education_share_secondary  \
# 1280                   47.35                      32.26
#
#       education_share_vocational  education_share_primary  \
# 1280                        8.24                     7.78
#
#       tourits_per_1000_persons  percent_population_below_25  \
# 1280                     710.8                    23.654267
#
#       percent_population_25_60  percent_population_over_60  \
# 1280                 57.049889                   16.437119
#
#       municipality_code_old election_presence percent_invalid_votes  \
# 1280                1465011               NaN                   NaN
#
#      voivodeship PIS_party KO_party KONFEDERACJA_party PSL_party SLD_party
# 1280         NaN       NaN      NaN                NaN       NaN       NaN

# %%
wars = pd.read_csv(r'..\wars.csv', sep=';')

# %%
wars
# Out:
#    Kod TERYT    Powiat  Województwo Frekwencja % głosów nieważnych  \
# 0     146501  Warszawa  mazowieckie      77,07                0,53
#
#   W tym z powodu postawienia znaku „X” obok nazwiska dwóch lub większej liczby kandydatów z różnych list  \
# 0                                              45,59
#
#   W tym z powodu niepostawienia znaku „X” obok nazwiska żadnego kandydata  \
# 0                                              54,41
#
#   W tym z powodu postawienia znaku „X” wyłącznie obok nazwiska kandydata na liście której rejestracja została unieważniona  \
# 0                                               0,00
#
#   % głosów ważnych  \
# 0            99,47
#
#   KOALICYJNY KOMITET WYBORCZY KOALICJA OBYWATELSKA PO .N IPL ZIELONI - ZPOW-601-6/19  \
# 0                                              42,96
#
#    KOMITET WYBORCZY AKCJA ZAWIEDZIONYCH EMERYTÓW RENCISTÓW - ZPOW-601-21/19  \
# 0                                                NaN
#
#   KOMITET WYBORCZY KONFEDERACJA WOLNOŚĆ I NIEPODLEGŁOŚĆ - ZPOW-601-5/19  \
# 0                                               6,37
#
#   KOMITET WYBORCZY POLSKIE STRONNICTWO LUDOWE - ZPOW-601-19/19  \
# 0                                               4,94
#
#    KOMITET WYBORCZY PRAWICA - ZPOW-601-20/19  \
# 0                                        NaN
#
#   KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ - ZPOW-601-9/19  \
# 0                                              28,26
#
#    KOMITET WYBORCZY SKUTECZNI PIOTRA LIROYA-MARCA - ZPOW-601-17/19  \
# 0                                                NaN
#
#   KOMITET WYBORCZY SOJUSZ LEWICY DEMOKRATYCZNEJ - ZPOW-601-1/19  \
# 0                                              17,47
#
#    KOMITET WYBORCZY WYBORCÓW KOALICJA BEZPARTYJNI I SAMORZĄDOWCY - ZPOW-601-10/19  \
# 0                                                NaN
#
#   KOMITET WYBORCZY WYBORCÓW MNIEJSZOŚĆ NIEMIECKA - ZPOW-601-15/19
# 0                                                  s

# %%
data_wars = [77.07, 0.53, 'mazowieckie', 28.26, 42.96, 6.37, 4.94, 17.47]

# Assuming the columns you want to assign to are in this order:
columns_to_assign = ['election_presence', 'percent_invalid_votes', 'voivodeship', 
                     'PIS_party', 'KO_party', 'KONFEDERACJA_party', 'PSL_party', 'SLD_party']

# Find the row index where municipality_code is 146501
row_index = municip_merged[municip_merged['municipality_code'] == 146501].index

# Assign values from data_wars to the specified columns
municip_merged.loc[row_index, columns_to_assign] = data_wars

# %%
municip_merged[municip_merged['municipality_code']==146501]
# Out:
#       municipality_code municipality_name  county_code  percent_vaccinated  \
# 1280             146501          Warszawa      1465000                76.0
#
#       population_total  population_total_m  population_total_f  area_km2  \
# 1280           1861774              858762             1003012       517
#
#       population_density  urbanization_rate  healthcare_advices  \
# 1280              3599.4              100.0           5698702.0
#
#       population_per_pharmacy  installations_network_gas  \
# 1280                     3093                       71.7
#
#       appartments_per_1000_persons  persons_per_library  \
# 1280                         555.1                 7026
#
#       library_readers_per_1000_persons  forests_area  unemployment_rate  \
# 1280                               189       2924.56                2.2
#
#       unemployment_rate_m  unemployment_rate_f  revenues_per_capita  \
# 1280                  2.2                  2.1              9970.89
#
#       revenues_per_capita_PIT  revenues_per_capita_CIT  net_scholarization  \
# 1280                  3302.09                   545.73               99.51
#
#           county_name  average_wage_relative  doctors_per_1000_persons  \
# 1280  m. st. Warszawa                  129.4                      48.9
#
#       education_share_higher  education_share_secondary  \
# 1280                   47.35                      32.26
#
#       education_share_vocational  education_share_primary  \
# 1280                        8.24                     7.78
#
#       tourits_per_1000_persons  percent_population_below_25  \
# 1280                     710.8                    23.654267
#
#       percent_population_25_60  percent_population_over_60  \
# 1280                 57.049889                   16.437119
#
#       municipality_code_old  election_presence  percent_invalid_votes  \
# 1280                1465011              77.07                   0.53
#
#       voivodeship  PIS_party  KO_party  KONFEDERACJA_party  PSL_party  \
# 1280  mazowieckie      28.26     42.96                6.37       4.94
#
#       SLD_party  percent_vaccinated_log
# 1280      17.47                 1.15268

# %%
import numpy as np
municip_merged['percent_vaccinated_log'] = municip_merged['percent_vaccinated'].map(lambda x: np.log(x/100/(1-x/100)))

# %%
municip_merged
# Out:
#       municipality_code municipality_name  county_code  percent_vaccinated  \
# 0                 20101       Bolesławiec       201000                56.9
# 1                 20102       Bolesławiec       201000                47.7
# 2                 20103          Gromadka       201000                49.5
# 3                 20104      Nowogrodziec       201000                47.5
# 4                 20105        Osiecznica       201000                52.2
# ...                 ...               ...          ...                 ...
# 2472             321804             Resko      3218000                55.0
# 2473             321805         Węgorzyno      3218000                51.9
# 2474             326101          Koszalin      3261000                61.0
# 2475             326201          Szczecin      3262000                65.1
# 2476             326301       Świnoujście      3263000                62.3
#
#       population_total  population_total_m  population_total_f  area_km2  \
# 0                37659               17610               20049        24
# 1                14967                7473                7494       289
# 2                 5156                2559                2597       268
# 3                14852                7414                7438       176
# 4                 7358                3703                3655       437
# ...                ...                 ...                 ...       ...
# 2472              7470                3744                3726       285
# 2473              6463                3260                3203       256
# 2474            106152               50107               56045        98
# 2475            397289              188454              208835       301
# 2476             40326               19356               20970       202
#
#       population_density  urbanization_rate  healthcare_advices  \
# 0                 1597.8              100.0            202393.0
# 1                   51.9                0.0             13532.0
# 2                   19.3                0.0             11221.0
# 3                   84.2               28.1             47211.0
# 4                   16.8                0.0             38508.0
# ...                  ...                ...                 ...
# 2472                26.2               54.2             12945.0
# 2473                25.2               41.2             12137.0
# 2474              1079.4              100.0            587171.0
# 2475              1321.7              100.0           1613617.0
# 2476               199.6              100.0            181472.0
#
#       population_per_pharmacy  installations_network_gas  \
# 0                        2092                       90.6
# 1                       14967                       28.8
# 2                        5156                        0.2
# 3                        3713                       14.2
# 4                        7358                        4.1
# ...                       ...                        ...
# 2472                     3735                       27.6
# 2473                     6463                        3.7
# 2474                     2308                       87.6
# 2475                     2614                       81.9
# 2476                     1920                       69.6
#
#      appartments_per_1000_persons  persons_per_library  \
# 0                           444.9                18830
# 1                           305.9                 2495
# 2                           345.8                 5156
# 3                           305.5                 2970
# 4                           397.0                 1226
# ...                           ...                  ...
# 2472                        373.1                 7470
# 2473                        371.2                 2154
# 2474                        451.4                 9650
# 2475                        473.7                11036
# 2476                        553.8                 6721
#
#       library_readers_per_1000_persons  forests_area  unemployment_rate  \
# 0                                  143         75.18                3.6
# 1                                  119        230.52                3.1
# 2                                   37        204.00                3.8
# 3                                   48        251.00                3.7
# 4                                  167         43.13                3.8
# ...                                ...           ...                ...
# 2472                                77        249.78               12.1
# 2473                               141        275.15                8.2
# 2474                               131        123.16                5.2
# 2475                               126       2745.55                3.1
# 2476                                76         83.94                3.0
#
#       unemployment_rate_m  unemployment_rate_f  revenues_per_capita  \
# 0                     3.1                  4.1              5312.66
# 1                     2.8                  3.5              5396.32
# 2                     2.7                  5.2              8219.43
# 3                     3.0                  4.6              5067.58
# 4                     3.3                  4.5              6377.16
# ...                   ...                  ...                  ...
# 2472                 11.5                 12.9              6000.71
# 2473                  5.4                 11.9              8185.84
# 2474                  4.9                  5.5              6985.42
# 2475                  3.1                  3.0              7659.20
# 2476                  2.7                  3.4             14981.14
#
#       revenues_per_capita_PIT  revenues_per_capita_CIT  net_scholarization  \
# 0                     1067.74                    56.58              113.11
# 1                      926.60                    11.74               68.29
# 2                      690.41                   162.36               89.37
# 3                      644.43                    30.53               84.88
# 4                      786.19                    27.93              100.15
# ...                       ...                      ...                 ...
# 2472                   878.57                    33.35               81.63
# 2473                   537.42                    20.72               71.07
# 2474                  1561.14                    96.76              105.84
# 2475                  1553.30                   107.36              101.78
# 2476                  1335.41                    78.14               98.19
#
#          county_name  average_wage_relative  doctors_per_1000_persons  \
# 0      bolesławiecki                   88.5                      14.3
# 1      bolesławiecki                   88.5                      14.3
# 2      bolesławiecki                   88.5                      14.3
# 3      bolesławiecki                   88.5                      14.3
# 4      bolesławiecki                   88.5                      14.3
# ...              ...                    ...                       ...
# 2472         łobeski                   85.3                       7.8
# 2473         łobeski                   85.3                       7.8
# 2474     m. Koszalin                   90.0                      39.5
# 2475     m. Szczecin                  103.1                      68.0
# 2476  m. Świnoujście                   99.9                      15.1
#
#       education_share_higher  education_share_secondary  \
# 0                      17.43                      35.08
# 1                      17.43                      35.08
# 2                      17.43                      35.08
# 3                      17.43                      35.08
# 4                      17.43                      35.08
# ...                      ...                        ...
# 2472                   12.98                      31.97
# 2473                   12.98                      31.97
# 2474                   29.82                      36.16
# 2475                   32.73                      34.85
# 2476                   22.58                      39.23
#
#       education_share_vocational  education_share_primary  \
# 0                          25.51                    15.85
# 1                          25.51                    15.85
# 2                          25.51                    15.85
# 3                          25.51                    15.85
# 4                          25.51                    15.85
# ...                          ...                      ...
# 2472                       25.33                    23.32
# 2473                       25.33                    23.32
# 2474                       16.67                    11.44
# 2475                       15.76                    10.81
# 2476                       19.42                    12.39
#
#       tourits_per_1000_persons  percent_population_below_25  \
# 0                       427.36                    21.349478
# 1                       427.36                    28.001604
# 2                       427.36                    25.019395
# 3                       427.36                    27.699973
# 4                       427.36                    28.146235
# ...                        ...                          ...
# 2472                    186.00                    24.939759
# 2473                    186.00                    26.226211
# 2474                      0.00                    21.740523
# 2475                    553.79                    21.919812
# 2476                   6948.44                    19.692010
#
#       percent_population_25_60  percent_population_over_60  \
# 0                    55.524576                   20.563478
# 1                    57.960847                   12.901717
# 2                    56.923972                   15.981381
# 3                    57.769997                   12.941018
# 4                    57.597173                   12.666485
# ...                        ...                         ...
# 2472                 55.876841                   16.840696
# 2473                 55.423178                   16.122544
# 2474                 55.757781                   19.907303
# 2475                 56.716899                   18.799161
# 2476                 57.603035                   20.686406
#
#       municipality_code_old election_presence percent_invalid_votes  \
# 0                    201011             60,88                  1,15
# 1                    201022             56,54                  1,47
# 2                    201032             52,83                  2,42
# 3                    201043             48,79                  1,91
# 4                    201052             49,94                  2,49
# ...                     ...               ...                   ...
# 2472                3218043             46,70                  2,40
# 2473                3218053             46,74                  1,92
# 2474                3261011             65,27                  1,01
# 2475                3262011             66,56                  0,74
# 2476                3263011             61,97                  0,70
#
#              voivodeship PIS_party KO_party KONFEDERACJA_party PSL_party  \
# 0           dolnośląskie     35,83    23,95               6,16      5,40
# 1           dolnośląskie     43,64    19,24               7,58      9,27
# 2           dolnośląskie     50,81    12,93               5,27      6,94
# 3           dolnośląskie     53,30    15,70               7,73      9,60
# 4           dolnośląskie     45,70    19,38               6,97      8,23
# ...                  ...       ...      ...                ...       ...
# 2472  zachodniopomorskie     40,66    28,53               5,29     11,01
# 2473  zachodniopomorskie     48,22    23,13               5,75     12,82
# 2474  zachodniopomorskie     29,59    38,39               5,96      7,75
# 2475  zachodniopomorskie     32,13    40,47               6,79      4,64
# 2476  zachodniopomorskie     30,18    33,44               5,32      4,36
#
#      SLD_party  percent_vaccinated_log
# 0        22,22                0.277772
# 1        14,94               -0.092065
# 2        19,28               -0.020001
# 3         9,75               -0.100083
# 4        15,61                0.088057
# ...        ...                     ...
# 2472     14,52                0.200671
# 2473     10,07                0.076037
# 2474     18,32                0.447312
# 2475     15,97                0.623438
# 2476     26,70                0.502301
#
# [2477 rows x 45 columns]

# %%
municip_merged.to_csv('..\_data\data_municipality_final.csv', index=False)

# %%
pd.read_csv('..\_data\data_municipality_final.csv')
# Out:
#       municipality_code municipality_name  county_code  percent_vaccinated  \
# 0                 20101       Bolesławiec       201000                56.9
# 1                 20102       Bolesławiec       201000                47.7
# 2                 20103          Gromadka       201000                49.5
# 3                 20104      Nowogrodziec       201000                47.5
# 4                 20105        Osiecznica       201000                52.2
# ...                 ...               ...          ...                 ...
# 2472             321804             Resko      3218000                55.0
# 2473             321805         Węgorzyno      3218000                51.9
# 2474             326101          Koszalin      3261000                61.0
# 2475             326201          Szczecin      3262000                65.1
# 2476             326301       Świnoujście      3263000                62.3
#
#       population_total  population_total_m  population_total_f  area_km2  \
# 0                37659               17610               20049        24
# 1                14967                7473                7494       289
# 2                 5156                2559                2597       268
# 3                14852                7414                7438       176
# 4                 7358                3703                3655       437
# ...                ...                 ...                 ...       ...
# 2472              7470                3744                3726       285
# 2473              6463                3260                3203       256
# 2474            106152               50107               56045        98
# 2475            397289              188454              208835       301
# 2476             40326               19356               20970       202
#
#       population_density  urbanization_rate  healthcare_advices  \
# 0                 1597.8              100.0            202393.0
# 1                   51.9                0.0             13532.0
# 2                   19.3                0.0             11221.0
# 3                   84.2               28.1             47211.0
# 4                   16.8                0.0             38508.0
# ...                  ...                ...                 ...
# 2472                26.2               54.2             12945.0
# 2473                25.2               41.2             12137.0
# 2474              1079.4              100.0            587171.0
# 2475              1321.7              100.0           1613617.0
# 2476               199.6              100.0            181472.0
#
#       population_per_pharmacy  installations_network_gas  \
# 0                        2092                       90.6
# 1                       14967                       28.8
# 2                        5156                        0.2
# 3                        3713                       14.2
# 4                        7358                        4.1
# ...                       ...                        ...
# 2472                     3735                       27.6
# 2473                     6463                        3.7
# 2474                     2308                       87.6
# 2475                     2614                       81.9
# 2476                     1920                       69.6
#
#      appartments_per_1000_persons  persons_per_library  \
# 0                           444.9                18830
# 1                           305.9                 2495
# 2                           345.8                 5156
# 3                           305.5                 2970
# 4                           397.0                 1226
# ...                           ...                  ...
# 2472                        373.1                 7470
# 2473                        371.2                 2154
# 2474                        451.4                 9650
# 2475                        473.7                11036
# 2476                        553.8                 6721
#
#       library_readers_per_1000_persons  forests_area  unemployment_rate  \
# 0                                  143         75.18                3.6
# 1                                  119        230.52                3.1
# 2                                   37        204.00                3.8
# 3                                   48        251.00                3.7
# 4                                  167         43.13                3.8
# ...                                ...           ...                ...
# 2472                                77        249.78               12.1
# 2473                               141        275.15                8.2
# 2474                               131        123.16                5.2
# 2475                               126       2745.55                3.1
# 2476                                76         83.94                3.0
#
#       unemployment_rate_m  unemployment_rate_f  revenues_per_capita  \
# 0                     3.1                  4.1              5312.66
# 1                     2.8                  3.5              5396.32
# 2                     2.7                  5.2              8219.43
# 3                     3.0                  4.6              5067.58
# 4                     3.3                  4.5              6377.16
# ...                   ...                  ...                  ...
# 2472                 11.5                 12.9              6000.71
# 2473                  5.4                 11.9              8185.84
# 2474                  4.9                  5.5              6985.42
# 2475                  3.1                  3.0              7659.20
# 2476                  2.7                  3.4             14981.14
#
#       revenues_per_capita_PIT  revenues_per_capita_CIT  net_scholarization  \
# 0                     1067.74                    56.58              113.11
# 1                      926.60                    11.74               68.29
# 2                      690.41                   162.36               89.37
# 3                      644.43                    30.53               84.88
# 4                      786.19                    27.93              100.15
# ...                       ...                      ...                 ...
# 2472                   878.57                    33.35               81.63
# 2473                   537.42                    20.72               71.07
# 2474                  1561.14                    96.76              105.84
# 2475                  1553.30                   107.36              101.78
# 2476                  1335.41                    78.14               98.19
#
#          county_name  average_wage_relative  doctors_per_1000_persons  \
# 0      bolesławiecki                   88.5                      14.3
# 1      bolesławiecki                   88.5                      14.3
# 2      bolesławiecki                   88.5                      14.3
# 3      bolesławiecki                   88.5                      14.3
# 4      bolesławiecki                   88.5                      14.3
# ...              ...                    ...                       ...
# 2472         łobeski                   85.3                       7.8
# 2473         łobeski                   85.3                       7.8
# 2474     m. Koszalin                   90.0                      39.5
# 2475     m. Szczecin                  103.1                      68.0
# 2476  m. Świnoujście                   99.9                      15.1
#
#       education_share_higher  education_share_secondary  \
# 0                      17.43                      35.08
# 1                      17.43                      35.08
# 2                      17.43                      35.08
# 3                      17.43                      35.08
# 4                      17.43                      35.08
# ...                      ...                        ...
# 2472                   12.98                      31.97
# 2473                   12.98                      31.97
# 2474                   29.82                      36.16
# 2475                   32.73                      34.85
# 2476                   22.58                      39.23
#
#       education_share_vocational  education_share_primary  \
# 0                          25.51                    15.85
# 1                          25.51                    15.85
# 2                          25.51                    15.85
# 3                          25.51                    15.85
# 4                          25.51                    15.85
# ...                          ...                      ...
# 2472                       25.33                    23.32
# 2473                       25.33                    23.32
# 2474                       16.67                    11.44
# 2475                       15.76                    10.81
# 2476                       19.42                    12.39
#
#       tourits_per_1000_persons  percent_population_below_25  \
# 0                       427.36                    21.349478
# 1                       427.36                    28.001604
# 2                       427.36                    25.019395
# 3                       427.36                    27.699973
# 4                       427.36                    28.146235
# ...                        ...                          ...
# 2472                    186.00                    24.939759
# 2473                    186.00                    26.226211
# 2474                      0.00                    21.740523
# 2475                    553.79                    21.919812
# 2476                   6948.44                    19.692010
#
#       percent_population_25_60  percent_population_over_60  \
# 0                    55.524576                   20.563478
# 1                    57.960847                   12.901717
# 2                    56.923972                   15.981381
# 3                    57.769997                   12.941018
# 4                    57.597173                   12.666485
# ...                        ...                         ...
# 2472                 55.876841                   16.840696
# 2473                 55.423178                   16.122544
# 2474                 55.757781                   19.907303
# 2475                 56.716899                   18.799161
# 2476                 57.603035                   20.686406
#
#       municipality_code_old election_presence percent_invalid_votes  \
# 0                    201011             60,88                  1,15
# 1                    201022             56,54                  1,47
# 2                    201032             52,83                  2,42
# 3                    201043             48,79                  1,91
# 4                    201052             49,94                  2,49
# ...                     ...               ...                   ...
# 2472                3218043             46,70                  2,40
# 2473                3218053             46,74                  1,92
# 2474                3261011             65,27                  1,01
# 2475                3262011             66,56                  0,74
# 2476                3263011             61,97                  0,70
#
#              voivodeship PIS_party KO_party KONFEDERACJA_party PSL_party  \
# 0           dolnośląskie     35,83    23,95               6,16      5,40
# 1           dolnośląskie     43,64    19,24               7,58      9,27
# 2           dolnośląskie     50,81    12,93               5,27      6,94
# 3           dolnośląskie     53,30    15,70               7,73      9,60
# 4           dolnośląskie     45,70    19,38               6,97      8,23
# ...                  ...       ...      ...                ...       ...
# 2472  zachodniopomorskie     40,66    28,53               5,29     11,01
# 2473  zachodniopomorskie     48,22    23,13               5,75     12,82
# 2474  zachodniopomorskie     29,59    38,39               5,96      7,75
# 2475  zachodniopomorskie     32,13    40,47               6,79      4,64
# 2476  zachodniopomorskie     30,18    33,44               5,32      4,36
#
#      SLD_party  percent_vaccinated_log
# 0        22,22                0.277772
# 1        14,94               -0.092065
# 2        19,28               -0.020001
# 3         9,75               -0.100083
# 4        15,61                0.088057
# ...        ...                     ...
# 2472     14,52                0.200671
# 2473     10,07                0.076037
# 2474     18,32                0.447312
# 2475     15,97                0.623438
# 2476     26,70                0.502301
#
# [2477 rows x 45 columns]

# %%
# !pip install pySAL
# Out:
# Requirement already satisfied: pySAL in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (24.1)
# Requirement already satisfied: libpysal>=4.6.2 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (4.10)
# Requirement already satisfied: access>=1.1.8 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (1.1.9)
# Requirement already satisfied: esda>=2.4.1 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (2.5.1)
# Requirement already satisfied: giddy>=2.3.3 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (2.3.5)
# Requirement already satisfied: inequality>=1.0.0 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (1.0.1)
# Requirement already satisfied: pointpats>=2.2.0 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (2.4.0)
# Requirement already satisfied: segregation>=2.3.1 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (2.5)
# Requirement already satisfied: spaghetti>=1.6.6 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (1.7.5.post1)
# Requirement already satisfied: mgwr>=2.1.2 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (2.2.1)
# Requirement already satisfied: momepy>=0.5.3 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (0.7.0)
# Requirement already satisfied: spglm>=1.0.8 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (1.1.0)
# Requirement already satisfied: spint>=1.0.7 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (1.0.7)
# Requirement already satisfied: spreg>=1.2.4 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (1.4.2)
# Requirement already satisfied: spvcm>=0.3.0 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (0.3.0)
# Requirement already satisfied: tobler>=0.8.2 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (0.11.2)
# Requirement already satisfied: mapclassify>=2.4.3 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (2.6.1)
# Requirement already satisfied: splot>=1.1.5.post1 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (1.1.5.post1)
# Requirement already satisfied: spopt>=0.4.1 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pySAL) (0.6.0)
# Requirement already satisfied: geopandas in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from access>=1.1.8->pySAL) (0.14.4)
# Requirement already satisfied: numpy>=1.3 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from access>=1.1.8->pySAL) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from access>=1.1.8->pySAL) (2.2.2)
# Requirement already satisfied: requests>=2 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from access>=1.1.8->pySAL) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from esda>=2.4.1->pySAL) (1.4.2)
# Requirement already satisfied: scipy>=1.9 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from esda>=2.4.1->pySAL) (1.13.0)
# Requirement already satisfied: quantecon>=0.4.7 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from giddy>=2.3.3->pySAL) (0.7.2)
# Requirement already satisfied: beautifulsoup4>=4.10 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from libpysal>=4.6.2->pySAL) (4.12.3)
# Requirement already satisfied: packaging>=22 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from libpysal>=4.6.2->pySAL) (24.0)
# Requirement already satisfied: platformdirs>=2.0.2 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from libpysal>=4.6.2->pySAL) (4.2.0)
# Requirement already satisfied: shapely>=2.0.1 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from libpysal>=4.6.2->pySAL) (2.0.4)
# Requirement already satisfied: networkx>=2.7 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from mapclassify>=2.4.3->pySAL) (3.3)
# Requirement already satisfied: tqdm>=4.63.0 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from momepy>=0.5.3->pySAL) (4.66.4)
# Requirement already satisfied: matplotlib in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pointpats>=2.2.0->pySAL) (3.8.4)
# Requirement already satisfied: deprecation in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from segregation>=2.3.1->pySAL) (2.1.0)
# Requirement already satisfied: joblib in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from segregation>=2.3.1->pySAL) (1.4.2)
# Requirement already satisfied: seaborn in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from segregation>=2.3.1->pySAL) (0.13.2)
# Requirement already satisfied: numba in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from segregation>=2.3.1->pySAL) (0.59.1)
# Requirement already satisfied: pyproj>=3 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from segregation>=2.3.1->pySAL) (3.6.1)
# Requirement already satisfied: rtree>=1.0 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from spaghetti>=1.6.6->pySAL) (1.2.0)
# Requirement already satisfied: pulp>=2.7 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from spopt>=0.4.1->pySAL) (2.8.0)
# Requirement already satisfied: rasterio in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from tobler>=0.8.2->pySAL) (1.3.10)
# Requirement already satisfied: statsmodels in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from tobler>=0.8.2->pySAL) (0.14.2)
# Requirement already satisfied: rasterstats in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from tobler>=0.8.2->pySAL) (0.19.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from beautifulsoup4>=4.10->libpysal>=4.6.2->pySAL) (2.5)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from geopandas->access>=1.1.8->pySAL) (1.9.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pandas>=0.23.4->access>=1.1.8->pySAL) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pandas>=0.23.4->access>=1.1.8->pySAL) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pandas>=0.23.4->access>=1.1.8->pySAL) (2024.1)
# Requirement already satisfied: certifi in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from pyproj>=3->segregation>=2.3.1->pySAL) (2024.2.2)
# Requirement already satisfied: sympy in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from quantecon>=0.4.7->giddy>=2.3.3->pySAL) (1.12)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from numba->segregation>=2.3.1->pySAL) (0.42.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from requests>=2->access>=1.1.8->pySAL) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from requests>=2->access>=1.1.8->pySAL) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from requests>=2->access>=1.1.8->pySAL) (2.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from scikit-learn>=1.0->esda>=2.4.1->pySAL) (3.5.0)
# Requirement already satisfied: colorama in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from tqdm>=4.63.0->momepy>=0.5.3->pySAL) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from matplotlib->pointpats>=2.2.0->pySAL) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from matplotlib->pointpats>=2.2.0->pySAL) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from matplotlib->pointpats>=2.2.0->pySAL) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from matplotlib->pointpats>=2.2.0->pySAL) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from matplotlib->pointpats>=2.2.0->pySAL) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from matplotlib->pointpats>=2.2.0->pySAL) (3.1.2)
# Requirement already satisfied: affine in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from rasterio->tobler>=0.8.2->pySAL) (2.4.0)
# Requirement already satisfied: attrs in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from rasterio->tobler>=0.8.2->pySAL) (23.2.0)
# Requirement already satisfied: click>=4.0 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from rasterio->tobler>=0.8.2->pySAL) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from rasterio->tobler>=0.8.2->pySAL) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from rasterio->tobler>=0.8.2->pySAL) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from rasterio->tobler>=0.8.2->pySAL) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from rasterio->tobler>=0.8.2->pySAL) (68.0.0)
# Requirement already satisfied: simplejson in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from rasterstats->tobler>=0.8.2->pySAL) (3.19.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from statsmodels->tobler>=0.8.2->pySAL) (0.5.6)
# Requirement already satisfied: six in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from fiona>=1.8.21->geopandas->access>=1.1.8->pySAL) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\janfrackowiak\anaconda3\envs\ml-env\lib\site-packages (from sympy->quantecon>=0.4.7->giddy>=2.3.3->pySAL) (1.3.0)

# %%
import pysal as ps
import numpy as np
import pandas as pd
import os
import ast
from shutil import copyfile

def df2dbf(df, dbf_path, my_specs=None):
    '''
    Convert a pandas.DataFrame into a dbf.

    __author__  = "Dani Arribas-Bel <darribas@asu.edu> "
    ...

    Arguments
    ---------
    df          : DataFrame
                  Pandas dataframe object to be entirely written out to a dbf
    dbf_path    : str
                  Path to the output dbf. It is also returned by the function
    my_specs    : list
                  List with the field_specs to use for each column.
                  Defaults to None and applies the following scheme:
                    * int: ('N', 14, 0)
                    * float: ('N', 14, 14)
                    * str: ('C', 14, 0)
    '''
    if my_specs:
        specs = my_specs
    else:
        type2spec = {int: ('N', 20, 0),
                     np.int64: ('N', 20, 0),
                     float: ('N', 36, 15),
                     np.float64: ('N', 36, 15),
                     str: ('C', 14, 0)
                     }
        types = [type(df[i].iloc[0]) for i in df.columns]
        specs = [type2spec[t] for t in types]
    db = ps.open(dbf_path, 'w')
    db.header = list(df.columns)
    db.field_spec = specs
    for i, row in df.T.iteritems():
        db.write(row)
    db.close()
    return dbf_path

# %%
municip_merged.isna().sum()
# Out:
# municipality_code                    0
# municipality_name                    0
# county_code                          0
# percent_vaccinated                   0
# population_total                     0
# population_total_m                   0
# population_total_f                   0
# area_km2                             0
# population_density                   0
# urbanization_rate                    0
# healthcare_advices                  59
# population_per_pharmacy              0
# installations_network_gas            0
# appartments_per_1000_persons         0
# persons_per_library                  0
# library_readers_per_1000_persons     0
# forests_area                        20
# unemployment_rate                    0
# unemployment_rate_m                  0
# unemployment_rate_f                  0
# revenues_per_capita                  0
# revenues_per_capita_PIT              0
# revenues_per_capita_CIT              0
# net_scholarization                   0
# county_name                          0
# average_wage_relative                0
# doctors_per_1000_persons             0
# education_share_higher               0
# education_share_secondary            0
# education_share_vocational           0
# education_share_primary              0
# tourits_per_1000_persons             1
# percent_population_below_25          0
# percent_population_25_60             0
# percent_population_over_60           0
# municipality_code_old                0
# election_presence                    0
# percent_invalid_votes                0
# voivodeship                          0
# PIS_party                            0
# KO_party                             0
# KONFEDERACJA_party                   0
# PSL_party                            0
# SLD_party                            0
# percent_vaccinated_log               0
# dtype: int64

# %%
import pandas as pd

# Get columns with missing values
columns_with_missing_values = municip_merged.columns[municip_merged.isnull().any()].tolist()

# Print the names of columns with missing values
print("Columns with missing values:")
for column in columns_with_missing_values:
    print(column)


# Group by 'county_code' and impute missing values in each group with the median
municip_merged[columns_with_missing_values] = municip_merged.groupby('county_code')[columns_with_missing_values].transform(lambda x: x.fillna(x.median()))

# Check if there are any remaining missing values
remaining_missing_values = municip_merged.isnull().sum().sum()
if remaining_missing_values == 0:
    print("All missing values have been imputed successfully.")
else:
    print(f"There are {remaining_missing_values} missing values remaining after imputation.")
# Out:
# Columns with missing values:
# healthcare_advices
# forests_area
# tourits_per_1000_persons
# There are 5 missing values remaining after imputation.

# %%
municip_merged.columns
# Out:
# Index(['municipality_code', 'municipality_name', 'county_code',
#        'percent_vaccinated', 'population_total', 'population_total_m',
#        'population_total_f', 'area_km2', 'population_density',
#        'urbanization_rate', 'healthcare_advices', 'population_per_pharmacy',
#        'installations_network_gas', 'appartments_per_1000_persons',
#        'persons_per_library', 'library_readers_per_1000_persons',
#        'forests_area', 'unemployment_rate', 'unemployment_rate_m',
#        'unemployment_rate_f', 'revenues_per_capita', 'revenues_per_capita_PIT',
#        'revenues_per_capita_CIT', 'net_scholarization', 'county_name',
#        'average_wage_relative', 'doctors_per_1000_persons',
#        'education_share_higher', 'education_share_secondary',
#        'education_share_vocational', 'education_share_primary',
#        'tourits_per_1000_persons', 'percent_population_below_25',
#        'percent_population_25_60', 'percent_population_over_60',
#        'municipality_code_old', 'election_presence', 'percent_invalid_votes',
#        'voivodeship', 'PIS_party', 'KO_party', 'KONFEDERACJA_party',
#        'PSL_party', 'SLD_party', 'percent_vaccinated_log'],
#       dtype='object')

# %%
import pandas as pd

# Get columns with missing values
columns_with_missing_values = municip_merged.columns[municip_merged.isnull().any()].tolist()

# Print the names of columns with missing values
print("Columns with missing values:")
for column in columns_with_missing_values:
    print(column)


# Group by 'county_code' and impute missing values in each group with the median
municip_merged[columns_with_missing_values] = municip_merged.groupby('voivodeship')[columns_with_missing_values].transform(lambda x: x.fillna(x.median()))

# Check if there are any remaining missing values
remaining_missing_values = municip_merged.isnull().sum().sum()
if remaining_missing_values == 0:
    print("All missing values have been imputed successfully.")
else:
    print(f"There are {remaining_missing_values} missing values remaining after imputation.")
# Out:
# Columns with missing values:
# forests_area
# tourits_per_1000_persons
# All missing values have been imputed successfully.

# %%
municip_merged.to_csv(r'..\_data\data_municipalities_final.csv', index=False)

# %%
municip_merged.dtypes
# Out:
# municipality_code                     int64
# municipality_name                    object
# county_code                           int64
# percent_vaccinated                  float64
# population_total                      int64
# population_total_m                    int64
# population_total_f                    int64
# area_km2                              int64
# population_density                  float64
# urbanization_rate                   float64
# healthcare_advices                  float64
# population_per_pharmacy               int64
# installations_network_gas           float64
# appartments_per_1000_persons        float64
# persons_per_library                   int64
# library_readers_per_1000_persons      int64
# forests_area                        float64
# unemployment_rate                   float64
# unemployment_rate_m                 float64
# unemployment_rate_f                 float64
# revenues_per_capita                 float64
# revenues_per_capita_PIT             float64
# revenues_per_capita_CIT             float64
# net_scholarization                  float64
# county_name                          object
# average_wage_relative               float64
# doctors_per_1000_persons            float64
# education_share_higher              float64
# education_share_secondary           float64
# education_share_vocational          float64
# education_share_primary             float64
# tourits_per_1000_persons            float64
# percent_population_below_25         float64
# percent_population_25_60            float64
# percent_population_over_60          float64
# municipality_code_old                 int64
# election_presence                   float64
# percent_invalid_votes               float64
# voivodeship                          object
# PIS_party                           float64
# KO_party                            float64
# KONFEDERACJA_party                  float64
# PSL_party                           float64
# SLD_party                           float64
# percent_vaccinated_log              float64
# dtype: object

# %%
# Assuming municip_merged is your DataFrame
columns_to_convert = ['appartments_per_1000_persons', 'election_presence', 'percent_invalid_votes', 'PIS_party', 'KO_party', 'KONFEDERACJA_party', 'PSL_party', 'SLD_party', 'percent_vaccinated_log']

for col in columns_to_convert:
    # Check if the column contains strings
    if municip_merged[col].dtype == 'object':
        # Replace spaces and commas with dots, then convert to float
        municip_merged[col] = municip_merged[col].str.replace(' ', '').str.replace(',', '.').astype(float)

# %%
data_wars = [77.07, 0.53, 'mazowieckie', 28.26, 42.96, 6.37, 4.94, 17.47]

# Assuming the columns you want to assign to are in this order:
columns_to_assign = ['election_presence', 'percent_invalid_votes', 'voivodeship', 
                     'PIS_party', 'KO_party', 'KONFEDERACJA_party', 'PSL_party', 'SLD_party']

# Find the row index where municipality_code is 146501
row_index = municip_merged[municip_merged['municipality_code'] == 146501].index

# Assign values from data_wars to the specified columns
municip_merged.loc[row_index, columns_to_assign] = data_wars

# %%
municip_merged.to_csv(r'..\_data\data_municipalities_final.csv', index=False)

# %%
municip_merged.isna().sum(
)
# Out:
# municipality_code                   0
# municipality_name                   0
# county_code                         0
# percent_vaccinated                  0
# population_total                    0
# population_total_m                  0
# population_total_f                  0
# area_km2                            0
# population_density                  0
# urbanization_rate                   0
# healthcare_advices                  0
# population_per_pharmacy             0
# installations_network_gas           0
# appartments_per_1000_persons        0
# persons_per_library                 0
# library_readers_per_1000_persons    0
# forests_area                        0
# unemployment_rate                   0
# unemployment_rate_m                 0
# unemployment_rate_f                 0
# revenues_per_capita                 0
# revenues_per_capita_PIT             0
# revenues_per_capita_CIT             0
# net_scholarization                  0
# county_name                         0
# average_wage_relative               0
# doctors_per_1000_persons            0
# education_share_higher              0
# education_share_secondary           0
# education_share_vocational          0
# education_share_primary             0
# tourits_per_1000_persons            0
# percent_population_below_25         0
# percent_population_25_60            0
# percent_population_over_60          0
# municipality_code_old               0
# election_presence                   0
# percent_invalid_votes               0
# voivodeship                         0
# PIS_party                           0
# KO_party                            0
# KONFEDERACJA_party                  0
# PSL_party                           0
# SLD_party                           0
# percent_vaccinated_log              0
# dtype: int64

# %%
municip_merged
# Out:
#       municipality_code municipality_name  county_code  percent_vaccinated  \
# 0                 20101       Bolesławiec       201000                56.9
# 1                 20102       Bolesławiec       201000                47.7
# 2                 20103          Gromadka       201000                49.5
# 3                 20104      Nowogrodziec       201000                47.5
# 4                 20105        Osiecznica       201000                52.2
# ...                 ...               ...          ...                 ...
# 2472             321804             Resko      3218000                55.0
# 2473             321805         Węgorzyno      3218000                51.9
# 2474             326101          Koszalin      3261000                61.0
# 2475             326201          Szczecin      3262000                65.1
# 2476             326301       Świnoujście      3263000                62.3
#
#       population_total  population_total_m  population_total_f  area_km2  \
# 0                37659               17610               20049        24
# 1                14967                7473                7494       289
# 2                 5156                2559                2597       268
# 3                14852                7414                7438       176
# 4                 7358                3703                3655       437
# ...                ...                 ...                 ...       ...
# 2472              7470                3744                3726       285
# 2473              6463                3260                3203       256
# 2474            106152               50107               56045        98
# 2475            397289              188454              208835       301
# 2476             40326               19356               20970       202
#
#       population_density  urbanization_rate  healthcare_advices  \
# 0                 1597.8              100.0            202393.0
# 1                   51.9                0.0             13532.0
# 2                   19.3                0.0             11221.0
# 3                   84.2               28.1             47211.0
# 4                   16.8                0.0             38508.0
# ...                  ...                ...                 ...
# 2472                26.2               54.2             12945.0
# 2473                25.2               41.2             12137.0
# 2474              1079.4              100.0            587171.0
# 2475              1321.7              100.0           1613617.0
# 2476               199.6              100.0            181472.0
#
#       population_per_pharmacy  installations_network_gas  \
# 0                        2092                       90.6
# 1                       14967                       28.8
# 2                        5156                        0.2
# 3                        3713                       14.2
# 4                        7358                        4.1
# ...                       ...                        ...
# 2472                     3735                       27.6
# 2473                     6463                        3.7
# 2474                     2308                       87.6
# 2475                     2614                       81.9
# 2476                     1920                       69.6
#
#       appartments_per_1000_persons  persons_per_library  \
# 0                            444.9                18830
# 1                            305.9                 2495
# 2                            345.8                 5156
# 3                            305.5                 2970
# 4                            397.0                 1226
# ...                            ...                  ...
# 2472                         373.1                 7470
# 2473                         371.2                 2154
# 2474                         451.4                 9650
# 2475                         473.7                11036
# 2476                         553.8                 6721
#
#       library_readers_per_1000_persons  forests_area  unemployment_rate  \
# 0                                  143         75.18                3.6
# 1                                  119        230.52                3.1
# 2                                   37        204.00                3.8
# 3                                   48        251.00                3.7
# 4                                  167         43.13                3.8
# ...                                ...           ...                ...
# 2472                                77        249.78               12.1
# 2473                               141        275.15                8.2
# 2474                               131        123.16                5.2
# 2475                               126       2745.55                3.1
# 2476                                76         83.94                3.0
#
#       unemployment_rate_m  unemployment_rate_f  revenues_per_capita  \
# 0                     3.1                  4.1              5312.66
# 1                     2.8                  3.5              5396.32
# 2                     2.7                  5.2              8219.43
# 3                     3.0                  4.6              5067.58
# 4                     3.3                  4.5              6377.16
# ...                   ...                  ...                  ...
# 2472                 11.5                 12.9              6000.71
# 2473                  5.4                 11.9              8185.84
# 2474                  4.9                  5.5              6985.42
# 2475                  3.1                  3.0              7659.20
# 2476                  2.7                  3.4             14981.14
#
#       revenues_per_capita_PIT  revenues_per_capita_CIT  net_scholarization  \
# 0                     1067.74                    56.58              113.11
# 1                      926.60                    11.74               68.29
# 2                      690.41                   162.36               89.37
# 3                      644.43                    30.53               84.88
# 4                      786.19                    27.93              100.15
# ...                       ...                      ...                 ...
# 2472                   878.57                    33.35               81.63
# 2473                   537.42                    20.72               71.07
# 2474                  1561.14                    96.76              105.84
# 2475                  1553.30                   107.36              101.78
# 2476                  1335.41                    78.14               98.19
#
#          county_name  average_wage_relative  doctors_per_1000_persons  \
# 0      bolesławiecki                   88.5                      14.3
# 1      bolesławiecki                   88.5                      14.3
# 2      bolesławiecki                   88.5                      14.3
# 3      bolesławiecki                   88.5                      14.3
# 4      bolesławiecki                   88.5                      14.3
# ...              ...                    ...                       ...
# 2472         łobeski                   85.3                       7.8
# 2473         łobeski                   85.3                       7.8
# 2474     m. Koszalin                   90.0                      39.5
# 2475     m. Szczecin                  103.1                      68.0
# 2476  m. Świnoujście                   99.9                      15.1
#
#       education_share_higher  education_share_secondary  \
# 0                      17.43                      35.08
# 1                      17.43                      35.08
# 2                      17.43                      35.08
# 3                      17.43                      35.08
# 4                      17.43                      35.08
# ...                      ...                        ...
# 2472                   12.98                      31.97
# 2473                   12.98                      31.97
# 2474                   29.82                      36.16
# 2475                   32.73                      34.85
# 2476                   22.58                      39.23
#
#       education_share_vocational  education_share_primary  \
# 0                          25.51                    15.85
# 1                          25.51                    15.85
# 2                          25.51                    15.85
# 3                          25.51                    15.85
# 4                          25.51                    15.85
# ...                          ...                      ...
# 2472                       25.33                    23.32
# 2473                       25.33                    23.32
# 2474                       16.67                    11.44
# 2475                       15.76                    10.81
# 2476                       19.42                    12.39
#
#       tourits_per_1000_persons  percent_population_below_25  \
# 0                       427.36                    21.349478
# 1                       427.36                    28.001604
# 2                       427.36                    25.019395
# 3                       427.36                    27.699973
# 4                       427.36                    28.146235
# ...                        ...                          ...
# 2472                    186.00                    24.939759
# 2473                    186.00                    26.226211
# 2474                      0.00                    21.740523
# 2475                    553.79                    21.919812
# 2476                   6948.44                    19.692010
#
#       percent_population_25_60  percent_population_over_60  \
# 0                    55.524576                   20.563478
# 1                    57.960847                   12.901717
# 2                    56.923972                   15.981381
# 3                    57.769997                   12.941018
# 4                    57.597173                   12.666485
# ...                        ...                         ...
# 2472                 55.876841                   16.840696
# 2473                 55.423178                   16.122544
# 2474                 55.757781                   19.907303
# 2475                 56.716899                   18.799161
# 2476                 57.603035                   20.686406
#
#       municipality_code_old  election_presence  percent_invalid_votes  \
# 0                    201011              60.88                   1.15
# 1                    201022              56.54                   1.47
# 2                    201032              52.83                   2.42
# 3                    201043              48.79                   1.91
# 4                    201052              49.94                   2.49
# ...                     ...                ...                    ...
# 2472                3218043              46.70                   2.40
# 2473                3218053              46.74                   1.92
# 2474                3261011              65.27                   1.01
# 2475                3262011              66.56                   0.74
# 2476                3263011              61.97                   0.70
#
#              voivodeship  PIS_party  KO_party  KONFEDERACJA_party  PSL_party  \
# 0           dolnośląskie      35.83     23.95                6.16       5.40
# 1           dolnośląskie      43.64     19.24                7.58       9.27
# 2           dolnośląskie      50.81     12.93                5.27       6.94
# 3           dolnośląskie      53.30     15.70                7.73       9.60
# 4           dolnośląskie      45.70     19.38                6.97       8.23
# ...                  ...        ...       ...                 ...        ...
# 2472  zachodniopomorskie      40.66     28.53                5.29      11.01
# 2473  zachodniopomorskie      48.22     23.13                5.75      12.82
# 2474  zachodniopomorskie      29.59     38.39                5.96       7.75
# 2475  zachodniopomorskie      32.13     40.47                6.79       4.64
# 2476  zachodniopomorskie      30.18     33.44                5.32       4.36
#
#       SLD_party  percent_vaccinated_log
# 0         22.22                0.277772
# 1         14.94               -0.092065
# 2         19.28               -0.020001
# 3          9.75               -0.100083
# 4         15.61                0.088057
# ...         ...                     ...
# 2472      14.52                0.200671
# 2473      10.07                0.076037
# 2474      18.32                0.447312
# 2475      15.97                0.623438
# 2476      26.70                0.502301
#
# [2477 rows x 45 columns]

# %%
partitions = pd.read_csv(r'..\\_data\\spatial_data.csv').drop['munic']
municip_merged = municip_merged.merge(partitions,left_on='municipality_code_old', right_on='municipality_code')

# %%
municip_merged = pd.get_dummies(municip_merged, columns=['partition'])
municip_merged
# Out:
#       municipality_code_x municipality_name_x  county_code  \
# 0                   20101         Bolesławiec       201000
# 1                   20102         Bolesławiec       201000
# 2                   20103            Gromadka       201000
# 3                   20104        Nowogrodziec       201000
# 4                   20105          Osiecznica       201000
# ...                   ...                 ...          ...
# 2713               321804               Resko      3218000
# 2714               321805           Węgorzyno      3218000
# 2715               326101            Koszalin      3261000
# 2716               326201            Szczecin      3262000
# 2717               326301         Świnoujście      3263000
#
#       percent_vaccinated  population_total  population_total_m  \
# 0                   56.9             37659               17610
# 1                   47.7             14967                7473
# 2                   49.5              5156                2559
# 3                   47.5             14852                7414
# 4                   52.2              7358                3703
# ...                  ...               ...                 ...
# 2713                55.0              7470                3744
# 2714                51.9              6463                3260
# 2715                61.0            106152               50107
# 2716                65.1            397289              188454
# 2717                62.3             40326               19356
#
#       population_total_f  area_km2  population_density  urbanization_rate  \
# 0                  20049        24              1597.8              100.0
# 1                   7494       289                51.9                0.0
# 2                   2597       268                19.3                0.0
# 3                   7438       176                84.2               28.1
# 4                   3655       437                16.8                0.0
# ...                  ...       ...                 ...                ...
# 2713                3726       285                26.2               54.2
# 2714                3203       256                25.2               41.2
# 2715               56045        98              1079.4              100.0
# 2716              208835       301              1321.7              100.0
# 2717               20970       202               199.6              100.0
#
#       healthcare_advices  population_per_pharmacy  installations_network_gas  \
# 0               202393.0                     2092                       90.6
# 1                13532.0                    14967                       28.8
# 2                11221.0                     5156                        0.2
# 3                47211.0                     3713                       14.2
# 4                38508.0                     7358                        4.1
# ...                  ...                      ...                        ...
# 2713             12945.0                     3735                       27.6
# 2714             12137.0                     6463                        3.7
# 2715            587171.0                     2308                       87.6
# 2716           1613617.0                     2614                       81.9
# 2717            181472.0                     1920                       69.6
#
#       appartments_per_1000_persons  persons_per_library  \
# 0                            444.9                18830
# 1                            305.9                 2495
# 2                            345.8                 5156
# 3                            305.5                 2970
# 4                            397.0                 1226
# ...                            ...                  ...
# 2713                         373.1                 7470
# 2714                         371.2                 2154
# 2715                         451.4                 9650
# 2716                         473.7                11036
# 2717                         553.8                 6721
#
#       library_readers_per_1000_persons  forests_area  unemployment_rate  \
# 0                                  143         75.18                3.6
# 1                                  119        230.52                3.1
# 2                                   37        204.00                3.8
# 3                                   48        251.00                3.7
# 4                                  167         43.13                3.8
# ...                                ...           ...                ...
# 2713                                77        249.78               12.1
# 2714                               141        275.15                8.2
# 2715                               131        123.16                5.2
# 2716                               126       2745.55                3.1
# 2717                                76         83.94                3.0
#
#       unemployment_rate_m  unemployment_rate_f  revenues_per_capita  \
# 0                     3.1                  4.1              5312.66
# 1                     2.8                  3.5              5396.32
# 2                     2.7                  5.2              8219.43
# 3                     3.0                  4.6              5067.58
# 4                     3.3                  4.5              6377.16
# ...                   ...                  ...                  ...
# 2713                 11.5                 12.9              6000.71
# 2714                  5.4                 11.9              8185.84
# 2715                  4.9                  5.5              6985.42
# 2716                  3.1                  3.0              7659.20
# 2717                  2.7                  3.4             14981.14
#
#       revenues_per_capita_PIT  revenues_per_capita_CIT  net_scholarization  \
# 0                     1067.74                    56.58              113.11
# 1                      926.60                    11.74               68.29
# 2                      690.41                   162.36               89.37
# 3                      644.43                    30.53               84.88
# 4                      786.19                    27.93              100.15
# ...                       ...                      ...                 ...
# 2713                   878.57                    33.35               81.63
# 2714                   537.42                    20.72               71.07
# 2715                  1561.14                    96.76              105.84
# 2716                  1553.30                   107.36              101.78
# 2717                  1335.41                    78.14               98.19
#
#          county_name  average_wage_relative  doctors_per_1000_persons  \
# 0      bolesławiecki                   88.5                      14.3
# 1      bolesławiecki                   88.5                      14.3
# 2      bolesławiecki                   88.5                      14.3
# 3      bolesławiecki                   88.5                      14.3
# 4      bolesławiecki                   88.5                      14.3
# ...              ...                    ...                       ...
# 2713         łobeski                   85.3                       7.8
# 2714         łobeski                   85.3                       7.8
# 2715     m. Koszalin                   90.0                      39.5
# 2716     m. Szczecin                  103.1                      68.0
# 2717  m. Świnoujście                   99.9                      15.1
#
#       education_share_higher  education_share_secondary  \
# 0                      17.43                      35.08
# 1                      17.43                      35.08
# 2                      17.43                      35.08
# 3                      17.43                      35.08
# 4                      17.43                      35.08
# ...                      ...                        ...
# 2713                   12.98                      31.97
# 2714                   12.98                      31.97
# 2715                   29.82                      36.16
# 2716                   32.73                      34.85
# 2717                   22.58                      39.23
#
#       education_share_vocational  education_share_primary  \
# 0                          25.51                    15.85
# 1                          25.51                    15.85
# 2                          25.51                    15.85
# 3                          25.51                    15.85
# 4                          25.51                    15.85
# ...                          ...                      ...
# 2713                       25.33                    23.32
# 2714                       25.33                    23.32
# 2715                       16.67                    11.44
# 2716                       15.76                    10.81
# 2717                       19.42                    12.39
#
#       tourits_per_1000_persons  percent_population_below_25  \
# 0                       427.36                    21.349478
# 1                       427.36                    28.001604
# 2                       427.36                    25.019395
# 3                       427.36                    27.699973
# 4                       427.36                    28.146235
# ...                        ...                          ...
# 2713                    186.00                    24.939759
# 2714                    186.00                    26.226211
# 2715                      0.00                    21.740523
# 2716                    553.79                    21.919812
# 2717                   6948.44                    19.692010
#
#       percent_population_25_60  percent_population_over_60  \
# 0                    55.524576                   20.563478
# 1                    57.960847                   12.901717
# 2                    56.923972                   15.981381
# 3                    57.769997                   12.941018
# 4                    57.597173                   12.666485
# ...                        ...                         ...
# 2713                 55.876841                   16.840696
# 2714                 55.423178                   16.122544
# 2715                 55.757781                   19.907303
# 2716                 56.716899                   18.799161
# 2717                 57.603035                   20.686406
#
#       municipality_code_old  election_presence  percent_invalid_votes  \
# 0                    201011              60.88                   1.15
# 1                    201022              56.54                   1.47
# 2                    201032              52.83                   2.42
# 3                    201043              48.79                   1.91
# 4                    201052              49.94                   2.49
# ...                     ...                ...                    ...
# 2713                3218043              46.70                   2.40
# 2714                3218053              46.74                   1.92
# 2715                3261011              65.27                   1.01
# 2716                3262011              66.56                   0.74
# 2717                3263011              61.97                   0.70
#
#              voivodeship  PIS_party  KO_party  KONFEDERACJA_party  PSL_party  \
# 0           dolnośląskie      35.83     23.95                6.16       5.40
# 1           dolnośląskie      43.64     19.24                7.58       9.27
# 2           dolnośląskie      50.81     12.93                5.27       6.94
# 3           dolnośląskie      53.30     15.70                7.73       9.60
# 4           dolnośląskie      45.70     19.38                6.97       8.23
# ...                  ...        ...       ...                 ...        ...
# 2713  zachodniopomorskie      40.66     28.53                5.29      11.01
# 2714  zachodniopomorskie      48.22     23.13                5.75      12.82
# 2715  zachodniopomorskie      29.59     38.39                5.96       7.75
# 2716  zachodniopomorskie      32.13     40.47                6.79       4.64
# 2717  zachodniopomorskie      30.18     33.44                5.32       4.36
#
#       SLD_party  percent_vaccinated_log  municipality_code_y  \
# 0         22.22                0.277772               201011
# 1         14.94               -0.092065               201022
# 2         19.28               -0.020001               201032
# 3          9.75               -0.100083               201043
# 4         15.61                0.088057               201052
# ...         ...                     ...                  ...
# 2713      14.52                0.200671              3218043
# 2714      10.07                0.076037              3218053
# 2715      18.32                0.447312              3261011
# 2716      15.97                0.623438              3262011
# 2717      26.70                0.502301              3263011
#
#      municipality_name_y  splag_percent_vaccinated  partition_austrian  \
# 0            Bolesławiec                 47.700000               False
# 1            Bolesławiec                 53.300000               False
# 2               Gromadka                 50.083333               False
# 3           Nowogrodziec                 50.550000               False
# 4             Osiecznica                 52.514286               False
# ...                  ...                       ...                 ...
# 2713               Resko                 54.957143               False
# 2714           Węgorzyno                 57.700000               False
# 2715            Koszalin                 55.616667               False
# 2716            Szczecin                 60.785714               False
# 2717         Świnoujście                 57.600000               False
#
#       partition_prussian  partition_russian
# 0                   True              False
# 1                   True              False
# 2                   True              False
# 3                   True              False
# 4                   True              False
# ...                  ...                ...
# 2713                True              False
# 2714                True              False
# 2715                True              False
# 2716                True              False
# 2717                True              False
#
# [2718 rows x 51 columns]

# %%
municip_merged.isna().sum()
# Out:
# county_code                         0
# percent_vaccinated                  0
# population_total                    0
# population_total_m                  0
# population_total_f                  0
# area_km2                            0
# population_density                  0
# urbanization_rate                   0
# healthcare_advices                  0
# population_per_pharmacy             0
# installations_network_gas           0
# appartments_per_1000_persons        0
# persons_per_library                 0
# library_readers_per_1000_persons    0
# forests_area                        0
# unemployment_rate                   0
# unemployment_rate_m                 0
# unemployment_rate_f                 0
# revenues_per_capita                 0
# revenues_per_capita_PIT             0
# revenues_per_capita_CIT             0
# net_scholarization                  0
# county_name                         0
# average_wage_relative               0
# doctors_per_1000_persons            0
# education_share_higher              0
# education_share_secondary           0
# education_share_vocational          0
# education_share_primary             0
# tourits_per_1000_persons            0
# percent_population_below_25         0
# percent_population_25_60            0
# percent_population_over_60          0
# municipality_code_old               0
# election_presence                   0
# percent_invalid_votes               0
# voivodeship                         0
# PIS_party                           0
# KO_party                            0
# KONFEDERACJA_party                  0
# PSL_party                           0
# SLD_party                           0
# percent_vaccinated_log              0
# splag_percent_vaccinated            0
# partition_austrian                  0
# partition_prussian                  0
# partition_russian                   0
# municipality_code                   0
# municipality_name                   0
# dtype: int64

# %%
municip_merged['municipality_code'] = municip_merged['municipality_code_x']
municip_merged['municipality_name'] = municip_merged['municipality_name_x']
municip_merged = municip_merged.drop(columns=['municipality_name_y','municipality_name_x','municipality_code_x','municipality_code_y'])
